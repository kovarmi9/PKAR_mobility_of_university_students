# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import LineString
from shapely.geometry import Point
import matplotlib.pyplot as plt
from pyproj import Transformer

# %%
# 1. Načti data
df = pd.read_excel('../../data/czech/data_czech.xlsx')

# 2. Ulož název krajů ze sloupce a nastav index
df = df.rename(columns={'University ↓ / Student →': 'origin'})
df = df.set_index('origin')

# 3. Očisti názvy (pro jistotu, kvůli shodě)
df.index = df.index.str.strip()
df.columns = df.columns.str.strip()

# 4. Pro každou krajskou kombinaci: pokud je řádek == sloupec → nastav 0
for region in df.index:
    if region in df.columns:
        df.at[region, region] = 0

# 5. Výstup pro kontrolu
print(df)
# Out:
#                       Hlavní město Praha  Středočeský kraj  Jihočeský kraj  \
# origin
# Hlavní město Praha                     0             24305            5838
# Jihomoravský kraj                    986              1432            1195
# Jihočeský kraj                       572              1268               0
# Královéhradecký kraj                 366               978             143
# Liberecký kraj                       324              1026              37
# Moravskoslezský kraj                 232               296              99
# Olomoucký kraj                       640               748             212
# Pardubický kraj                      262               962              76
# Plzeňský kraj                        657              1243            1229
# Středočeský kraj                     548                 0             141
# Kraj Vysočina                         40                91             117
# Zlínský kraj                         132               126              41
# Ústecký kraj                         410               827              78
#
#                       Plzeňský kraj  Karlovarský kraj  Ústecký kraj  \
# origin
# Hlavní město Praha             4205              2652          6997
# Jihomoravský kraj               316               226           555
# Jihočeský kraj                  984               197           211
# Královéhradecký kraj             80                67           269
# Liberecký kraj                   41                46           655
# Moravskoslezský kraj             80                35           283
# Olomoucký kraj                  167               101           297
# Pardubický kraj                  94                33           125
# Plzeňský kraj                     0              1352           951
# Středočeský kraj                103                83           232
# Kraj Vysočina                     9                 6            11
# Zlínský kraj                     25                10            51
# Ústecký kraj                     94               388             0
#
#                       Liberecký kraj  Královéhradecký kraj  Pardubický kraj  \
# origin
# Hlavní město Praha              4035                  4703             3343
# Jihomoravský kraj                458                  1590             2648
# Jihočeský kraj                   109                    78              111
# Královéhradecký kraj             475                     0             1519
# Liberecký kraj                     0                   711               87
# Moravskoslezský kraj             109                   228              400
# Olomoucký kraj                   281                   801             1621
# Pardubický kraj                  265                  1344                0
# Plzeňský kraj                    182                   146              100
# Středočeský kraj                 231                   173               51
# Kraj Vysočina                     10                    19               67
# Zlínský kraj                      36                   112              178
# Ústecký kraj                     516                   108               51
#
#                       Kraj Vysočina  Jihomoravský kraj  Olomoucký kraj  \
# origin
# Hlavní město Praha             3160               3240            2056
# Jihomoravský kraj              5103                  0            3690
# Jihočeský kraj                 1081                178              67
# Královéhradecký kraj            443                177             170
# Liberecký kraj                   48                 49              25
# Moravskoslezský kraj            233                718            1989
# Olomoucký kraj                  644               2230               0
# Pardubický kraj                 384                208             180
# Plzeňský kraj                   140                 75              53
# Středočeský kraj                 65                 37              27
# Kraj Vysočina                     0                261              30
# Zlínský kraj                    198               1348            1240
# Ústecký kraj                     53                 52              24
#
#                       Zlínský kraj  Moravskoslezský kraj
# origin
# Hlavní město Praha            2077                  3449
# Jihomoravský kraj             4856                  4570
# Jihočeský kraj                  36                    78
# Královéhradecký kraj           136                   224
# Liberecký kraj                  17                    42
# Moravskoslezský kraj          1423                     0
# Olomoucký kraj                2833                  4082
# Pardubický kraj                 98                   189
# Plzeňský kraj                   66                    85
# Středočeský kraj                24                    39
# Kraj Vysočina                   14                    15
# Zlínský kraj                     0                   655
# Ústecký kraj                    26                    39

# %%
# Příchozí studenti do každého kraje
prichozi = df.sum(axis=1).rename('prichozi')

print(prichozi)
# Out:
# origin
# Hlavní město Praha      70060
# Jihomoravský kraj       27625
# Jihočeský kraj           4970
# Královéhradecký kraj     5047
# Liberecký kraj           3108
# Moravskoslezský kraj     6125
# Olomoucký kraj          14657
# Pardubický kraj          4220
# Plzeňský kraj            6279
# Středočeský kraj         1754
# Kraj Vysočina             690
# Zlínský kraj             4152
# Ústecký kraj             2666
# Name: prichozi, dtype: int64

# %%
# Odchozí studenti z každého kraje
odchozi = df.sum(axis=0).rename('odchozi')

print(odchozi)
# Out:
# Hlavní město Praha       5169
# Středočeský kraj        33302
# Jihočeský kraj           9206
# Plzeňský kraj            6198
# Karlovarský kraj         5196
# Ústecký kraj            10637
# Liberecký kraj           6707
# Královéhradecký kraj    10013
# Pardubický kraj         10176
# Kraj Vysočina           11552
# Jihomoravský kraj        8573
# Olomoucký kraj           9551
# Zlínský kraj            11606
# Moravskoslezský kraj    13467
# Name: odchozi, dtype: int64

# %%
# Load spatial regions
gdf = gpd.read_file('../../data/czech/regions.gpkg')

# Keep only necessary columns and compute centroids
gdf = gdf[['nazev', 'geometry']]

# Compute default centroids
gdf['centroid'] = gdf.representative_point()

# Prepare transformation from WGS84 to the CRS of gdf
transformer = Transformer.from_crs("EPSG:4326", gdf.crs, always_xy=True)

# Manually define centroid in WGS84 and transform it to target CRS
x, y = transformer.transform(14.9, 49.9)  # longitude, latitude
manual_centroids = {
    'Středočeský kraj': Point(x, y)
}

# Apply manual centroid if match is found
gdf['centroid'] = gdf.apply(
    lambda row: manual_centroids.get(row['nazev'], row['centroid']),
    axis=1
)

# Show the result
gdf.head()
# Out:
#                 nazev                                           geometry  \
# 0  Hlavní město Praha  MULTIPOLYGON (((4644153.668 3017220.732, 46441...
# 1      Jihočeský kraj  MULTIPOLYGON (((4614559.886 2946839.972, 46145...
# 2       Plzeňský kraj  MULTIPOLYGON (((4557165.672 3003874.933, 45571...
# 3    Karlovarský kraj  MULTIPOLYGON (((4521107.248 3042368.86, 452110...
# 4      Liberecký kraj  MULTIPOLYGON (((4672911.633 3113397.259, 46729...
#
#                           centroid
# 0   POINT (4639467.91 3003862.303)
# 1  POINT (4654601.927 2896211.668)
# 2  POINT (4550638.407 2940237.936)
# 3  POINT (4521473.796 3010694.452)
# 4  POINT (4673165.965 3082051.107)

# %%
# Převod na DataFrame a zajištění správného indexu
df_prichozi = prichozi.reset_index().set_index('origin')
df_odchozi = odchozi.reset_index().set_index('index')
df_prichozi
# Out:
#                       prichozi
# origin
# Hlavní město Praha       70060
# Jihomoravský kraj        27625
# Jihočeský kraj            4970
# Královéhradecký kraj      5047
# Liberecký kraj            3108
# Moravskoslezský kraj      6125
# Olomoucký kraj           14657
# Pardubický kraj           4220
# Plzeňský kraj             6279
# Středočeský kraj          1754
# Kraj Vysočina              690
# Zlínský kraj              4152
# Ústecký kraj              2666

# %%
# Nejdřív merge příchozích
gdf = gdf.merge(df_prichozi, left_on='nazev', right_index=True, how='left')

# Potom merge odchozích
gdf = gdf.merge(df_odchozi, left_on='nazev', right_index=True, how='left')

# Vyplníme případné NaNy nulou
gdf[['prichozi', 'odchozi']] = gdf[['prichozi', 'odchozi']].fillna(0).astype(int)
gdf
# Out:
#                    nazev                                           geometry  \
# 0     Hlavní město Praha  MULTIPOLYGON (((4644153.668 3017220.732, 46441...
# 1         Jihočeský kraj  MULTIPOLYGON (((4614559.886 2946839.972, 46145...
# 2          Plzeňský kraj  MULTIPOLYGON (((4557165.672 3003874.933, 45571...
# 3       Karlovarský kraj  MULTIPOLYGON (((4521107.248 3042368.86, 452110...
# 4         Liberecký kraj  MULTIPOLYGON (((4672911.633 3113397.259, 46729...
# 5        Pardubický kraj  MULTIPOLYGON (((4732869.806 3022958.327, 47329...
# 6          Kraj Vysočina  MULTIPOLYGON (((4715791.911 2986533.031, 47157...
# 7      Jihomoravský kraj  MULTIPOLYGON (((4793943.251 2967571.59, 479396...
# 8         Olomoucký kraj  MULTIPOLYGON (((4809079.189 3059724.075, 48090...
# 9   Moravskoslezský kraj  MULTIPOLYGON (((4867703.925 3049792.801, 48677...
# 10          Zlínský kraj  MULTIPOLYGON (((4892848.604 2966990.43, 489285...
# 11  Královéhradecký kraj  MULTIPOLYGON (((4710982.717 3088954.652, 47109...
# 12      Středočeský kraj  MULTIPOLYGON (((4668253.871 3067568.647, 46682...
# 13          Ústecký kraj  MULTIPOLYGON (((4621792.628 3112706.241, 46217...
#
#                            centroid  prichozi  odchozi
# 0    POINT (4639467.91 3003862.303)     70060     5169
# 1   POINT (4654601.927 2896211.668)      4970     9206
# 2   POINT (4550638.407 2940237.936)      6279     6198
# 3   POINT (4521473.796 3010694.452)         0     5196
# 4   POINT (4673165.965 3082051.107)      3108     6707
# 5   POINT (4761771.754 2996765.661)      4220    10176
# 6    POINT (4724845.327 2936043.03)       690    11552
# 7   POINT (4808459.225 2913016.631)     27625     8573
# 8   POINT (4821430.019 2996129.084)     14657     9551
# 9   POINT (4885595.656 3003867.756)      6125    13467
# 10  POINT (4876253.041 2928355.199)      4152    11606
# 11  POINT (4726242.141 3049833.568)      5047    10013
# 12  POINT (4672781.636 2988134.478)      1754    33302
# 13  POINT (4595657.707 3057737.888)      2666    10637

# %%
gdf['celkem'] = gdf['prichozi'] + gdf['odchozi']
gdf
# Out:
#                    nazev                                           geometry  \
# 0     Hlavní město Praha  MULTIPOLYGON (((4644153.668 3017220.732, 46441...
# 1         Jihočeský kraj  MULTIPOLYGON (((4614559.886 2946839.972, 46145...
# 2          Plzeňský kraj  MULTIPOLYGON (((4557165.672 3003874.933, 45571...
# 3       Karlovarský kraj  MULTIPOLYGON (((4521107.248 3042368.86, 452110...
# 4         Liberecký kraj  MULTIPOLYGON (((4672911.633 3113397.259, 46729...
# 5        Pardubický kraj  MULTIPOLYGON (((4732869.806 3022958.327, 47329...
# 6          Kraj Vysočina  MULTIPOLYGON (((4715791.911 2986533.031, 47157...
# 7      Jihomoravský kraj  MULTIPOLYGON (((4793943.251 2967571.59, 479396...
# 8         Olomoucký kraj  MULTIPOLYGON (((4809079.189 3059724.075, 48090...
# 9   Moravskoslezský kraj  MULTIPOLYGON (((4867703.925 3049792.801, 48677...
# 10          Zlínský kraj  MULTIPOLYGON (((4892848.604 2966990.43, 489285...
# 11  Královéhradecký kraj  MULTIPOLYGON (((4710982.717 3088954.652, 47109...
# 12      Středočeský kraj  MULTIPOLYGON (((4668253.871 3067568.647, 46682...
# 13          Ústecký kraj  MULTIPOLYGON (((4621792.628 3112706.241, 46217...
#
#                            centroid  prichozi  odchozi  celkem
# 0    POINT (4639467.91 3003862.303)     70060     5169   75229
# 1   POINT (4654601.927 2896211.668)      4970     9206   14176
# 2   POINT (4550638.407 2940237.936)      6279     6198   12477
# 3   POINT (4521473.796 3010694.452)         0     5196    5196
# 4   POINT (4673165.965 3082051.107)      3108     6707    9815
# 5   POINT (4761771.754 2996765.661)      4220    10176   14396
# 6    POINT (4724845.327 2936043.03)       690    11552   12242
# 7   POINT (4808459.225 2913016.631)     27625     8573   36198
# 8   POINT (4821430.019 2996129.084)     14657     9551   24208
# 9   POINT (4885595.656 3003867.756)      6125    13467   19592
# 10  POINT (4876253.041 2928355.199)      4152    11606   15758
# 11  POINT (4726242.141 3049833.568)      5047    10013   15060
# 12  POINT (4672781.636 2988134.478)      1754    33302   35056
# 13  POINT (4595657.707 3057737.888)      2666    10637   13303

# %%
# 1. Set up the figure and axes
fig, ax = plt.subplots(1, 1, figsize=(12, 10))

# 2. Plot regional polygons (e.g., administrative boundaries)
gdf.plot(ax=ax, color='lightgrey', edgecolor='white')

# 3. Plot centroids for total number of students (in red)
gdf.set_geometry('centroid').plot(
    ax=ax,
    markersize=gdf['celkem'] / 100,  # Scale by total number of students
    color='red',                     # Red color for total students
    alpha=0.7,                       # Transparency
    label='Total number of students'
)

# 4. Plot centroids for incoming students (in green)
gdf.set_geometry('centroid').plot(
    ax=ax,
    markersize=gdf['prichozi'] / 100,  # Scale by number of incoming students
    color='limegreen',                 # Green color for incoming students
    alpha=0.7,                         # Transparency
    label='Incoming students'
)

# 5. Add title, legend, and final layout adjustments
ax.set_title("Ratio of incoming (green) to total (red) students by region", fontsize=16)
ax.axis('off')
ax.legend()
plt.tight_layout()
plt.show()

# %%
# Assign the 'centroid' column as the new geometry
gdf['geometry'] = gdf['centroid']

# Drop the original 'centroid' column
gdf = gdf.drop(columns='centroid')

# Set the correct coordinate reference system – EPSG:3035 (ETRS89 / LAEA Europe)
gdf = gdf.set_crs(epsg=3035)

# Export to GeoPackage
gdf.to_file('../../data/czech/czech_regions_points.gpkg', driver='GPKG', layer='centroid_data')

print("✅ GeoPackage successfully exported as 'data/czech/czech_regions_points.gpkg' in EPSG:3035.")
# Out:
# ✅ GeoPackage successfully exported as 'data/czech/czech_regions_points.gpkg' in EPSG:3035.
